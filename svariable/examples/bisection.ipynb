# %%
import sys
sys.path.append("..")
from bisection.bisection import bisection
import sympy as sp
from sympy.plotting import plot as symplot
import pandas as pd
import numpy as np
from numpy import linspace
import matplotlib.pyplot as plt
from IPython.display import Math, Latex, Markdown

# %%
# Definimos la función de la cual queremos buscar las raíces

r = sp.symbols('r')
E = (1 /(2*r**2) - (5 / r) + 1)
E = sp.lambdify(r, E)

# %%
# Representamos los valores de la energía para ver por dónde pueden encontrarse las raíces

x_vals = linspace(-10, 10, 100)
y_vals = E(x_vals)

plt.plot(x_vals, y_vals, color="b")
plt.plot(x_vals, y_vals)
plt.axhline(y=0, color="black")
plt.axvline(x=0, color="black")
plt.ylim([-12, 12])
plt.ylabel("E")
plt.xlabel("r")
plt.title("Energía en función del radio")
plt.show()

# %% [markdown]
# ## Solución con el método de la bisección

# %% [markdown]
# Vemos que hay dos raíces, la primera parece estar entre 0 y 1 y la segunda entre 4 y 6. Por lo tanto, vamos a aplicar el método de la bisección entre los dos intervalos

# %% [markdown]
# ## Primera raíz ($p_1$)

# %%
# Parametros del método de la bisección. intervalo aproximado, tolerancia y numero de iteraciones
a1 = 0.01
b1 = 1
tol = 1e-5
N0 = 20

# %%
p1, data1, convergence = bisection(E, a1, b1, tol, N0)

# %%
# Tabulate the data            
pd.set_option('display.precision', 10)
data1 = pd.DataFrame({'$a_n$':data1['a_matrix'],
                     '$b_n$' : data1['b_matrix'],
                     "$p_n$" : data1['p_matrix'],
                     "$f(p_{n})$" : data1['f_matrix'],
                     '$Error (\\frac{b_n - a_n}{2})$': data1['error_matrix']
                      })

data1.index = np.arange(1, len(data1) + 1, 1)
data1.index.name = '$n$'
data1 = data1[['$a_n$','$b_n$',"$p_n$", "$f(p_{n})$", '$Error (\\frac{b_n - a_n}{2})$']]

# %%
if convergence:
    print('Raíz: {} con intervalo inicial: ({}, {}) y tolerancia {} después de  {} iteraciones.'.format(p1, a1, b1, tol, len(data1) + 1))
    print('')
    display(data1)
else:
    print(p1)
# Out:
# Raíz: 0.10207984924316406 con intervalo inicial: (0.01, 1) y tolerancia 1e-05 después de  18 iteraciones.
#             $a_n$         $b_n$         $p_n$     $f(p_{n})$  \
# $n$
# 1    0.0100000000  1.0000000000  0.5050000000  -6.9403980002
# 2    0.0100000000  0.5050000000  0.2575000000 -10.8767084551
# 3    0.0100000000  0.2575000000  0.1337500000  -8.4331382654
# 4    0.0100000000  0.1337500000  0.0718750000  28.2211720227
# 5    0.0718750000  0.1337500000  0.1028125000  -0.3303646493
# 6    0.0718750000  0.1028125000  0.0873437500   9.2949043302
# 7    0.0873437500  0.1028125000  0.0950781250   3.7223212109
# 8    0.0950781250  0.1028125000  0.0989453125   1.5386458947
# 9    0.0989453125  0.1028125000  0.1008789062   0.5681709773
# 10   0.1008789062  0.1028125000  0.1018457031   0.1102941826
# 11   0.1018457031  0.1028125000  0.1023291016  -0.1121416587
# 12   0.1018457031  0.1023291016  0.1020874023  -0.0014559814
# 13   0.1018457031  0.1020874023  0.1019665527   0.0542853274
# 14   0.1019665527  0.1020874023  0.1020269775   0.0263813191
# 15   0.1020269775  0.1020874023  0.1020571899   0.0124543415
# 16   0.1020571899  0.1020874023  0.1020722961   0.0054970996
# 17   0.1020722961  0.1020874023  0.1020798492   0.0020200392
#
#      $Error (\frac{b_n - a_n}{2})$
# $n$
# 1                     0.4950000000
# 2                     0.2475000000
# 3                     0.1237500000
# 4                     0.0618750000
# 5                     0.0309375000
# 6                     0.0154687500
# 7                     0.0077343750
# 8                     0.0038671875
# 9                     0.0019335938
# 10                    0.0009667969
# 11                    0.0004833984
# 12                    0.0002416992
# 13                    0.0001208496
# 14                    0.0000604248
# 15                    0.0000302124
# 16                    0.0000151062
# 17                    0.0000075531

# %% [markdown]
# ## Segunda raíz ($p_2$)

# %%
# Parametros del método de la bisección. intervalo aproximado, tolerancia y numero de iteraciones
a2 = 4
b2 = 6
tol = 1e-5
N0 = 20

# %%
p2, data2, convergence = bisection(E, a2, b2, tol, N0)

# %%
# Tabulate the data            
pd.set_option('display.precision', 10)
data2 = pd.DataFrame({'$a_n$':data2['a_matrix'],
                     '$b_n$' : data2['b_matrix'],
                     "$p_n$" : data2['p_matrix'],
                     "$f(p_{n})$" : data2['f_matrix'],
                     '$Error (\\frac{b_n - a_n}{2})$': data2['error_matrix']
                      })

data2.index = np.arange(1, len(data2) + 1, 1)
data2.index.name = '$n$'
data2 = data2[['$a_n$','$b_n$',"$p_n$", "$f(p_{n})$", '$Error (\\frac{b_n - a_n}{2})$']]

# %%
if convergence:
    print('Raíz: {} con intervalo inicial: ({}, {}) y tolerancia {} después de  {} iteraciones.'.format(p2, a2, b2, tol, len(data2) + 1))
    print('')
    display(data2)
else:
    print(p2)
# Out:
# Raíz: 4.897911071777344 con intervalo inicial: (4, 6) y tolerancia 1e-05 después de  19 iteraciones.
#             $a_n$         $b_n$         $p_n$    $f(p_{n})$  \
# $n$
# 1    4.0000000000  6.0000000000  5.0000000000  0.0200000000
# 2    4.0000000000  5.0000000000  4.5000000000 -0.0864197531
# 3    4.5000000000  5.0000000000  4.7500000000 -0.0304709141
# 4    4.7500000000  5.0000000000  4.8750000000 -0.0046022354
# 5    4.8750000000  5.0000000000  4.9375000000  0.0078513059
# 6    4.8750000000  4.9375000000  4.9062500000  0.0016633535
# 7    4.8750000000  4.9062500000  4.8906250000 -0.0014596454
# 8    4.8906250000  4.9062500000  4.8984375000  0.0001042915
# 9    4.8906250000  4.8984375000  4.8945312500 -0.0006770662
# 10   4.8945312500  4.8984375000  4.8964843750 -0.0002862348
# 11   4.8964843750  4.8984375000  4.8974609375 -0.0000909336
# 12   4.8974609375  4.8984375000  4.8979492188  0.0000066885
# 13   4.8974609375  4.8979492188  4.8977050781 -0.0000421202
# 14   4.8977050781  4.8979492188  4.8978271484 -0.0000177153
# 15   4.8978271484  4.8979492188  4.8978881836 -0.0000055132
# 16   4.8978881836  4.8979492188  4.8979187012  0.0000005876
# 17   4.8978881836  4.8979187012  4.8979034424 -0.0000024628
# 18   4.8979034424  4.8979187012  4.8979110718 -0.0000009376
#
#      $Error (\frac{b_n - a_n}{2})$
# $n$
# 1                     1.0000000000
# 2                     0.5000000000
# 3                     0.2500000000
# 4                     0.1250000000
# 5                     0.0625000000
# 6                     0.0312500000
# 7                     0.0156250000
# 8                     0.0078125000
# 9                     0.0039062500
# 10                    0.0019531250
# 11                    0.0009765625
# 12                    0.0004882812
# 13                    0.0002441406
# 14                    0.0001220703
# 15                    0.0000610352
# 16                    0.0000305176
# 17                    0.0000152588
# 18                    0.0000076294

# %%
# Guardamos los datos tabulados como un archivo de latex
data1.to_latex("latex/bisection/bisection_raiz1.tex")
data2.to_latex("latex/bisection/bisection_raiz2.tex")
data1.to_csv("csv/bisection/bisection_raiz1.csv", index = None, header = True)
